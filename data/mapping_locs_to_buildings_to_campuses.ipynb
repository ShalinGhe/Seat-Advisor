# %%
map_building = {    # ignore 1: Lernzentrum UB and 2: Bonatzbau, because we are looking at quiet work areas only
    3:  "Lesesaal",
    4:  "Ammerbau",
    5:  "Ammerbau",
    6:  "Ammerbau",
    7:  "Ammerbau", # ignore 8: Doktorandenbereich because it is not open to us
    9:  "Ammerbau",
    10: "Ammerbau",
    11: "Ammerbau",
    12: "Ammerbau",
    13: "Ammerbau",
    14: "Ammerbau",
    15: "Waschhalle",
    16: "Waschhalle",
    17: "Bereichsbib",
    18: "PCB",
    19: "PCB" 
    #20: "Lernzentrum MST" # ignore for now (unless Jessica finds out it is still accessible)
}

map_campus = {
    "Lesesaal": "Tal",
    "Ammerbau" : "Tal",
    "Waschhalle": "Tal",
    "Bereichsbib": "Mst",
    "PCB": "Mst"
}
